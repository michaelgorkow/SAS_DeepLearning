# %%
from swat import CAS
from dlpy.utils import *
from dlpy.applications import *
from dlpy.model import *
from dlpy.images import *
from dlpy.lr_scheduler import *
from dlpy.splitting import two_way_split
import cv2

# %%
s = CAS('localhost', 5570, 'sas', 'Orion123')

# %% [markdown]
# ## Load Images and their labels - Visualize training data
# This function creates a ready-to-train image table including all images and the corresponding object labels.

# %%
object_detection_targets = create_object_detection_table(conn=s,
                                                         data_path='/data/notebooks/deep_learning_examples/Aircraft Turnaround Management/training_images/',
                                                         local_path='/data/notebooks/deep_learning_examples/Aircraft Turnaround Management/training_images/',
                                                         coord_type='yolo', 
                                                         output='detTbl', 
                                                         image_size=(416,416))
object_detection_targets.insert(0, '_nObjects_')
# Out:
# NOTE: Images are loaded and processed.
# NOTE: Object detection table is successfully created.

# %%
# Object detection targets = _nObjects_ + 5 variables per object (label,x,y,width,height)
object_detection_targets[0:11]
# Out:
# ['_nObjects_',
#  '_Object0_',
#  '_Object0_x',
#  '_Object0_y',
#  '_Object0_width',
#  '_Object0_height',
#  '_Object1_',
#  '_Object1_x',
#  '_Object1_y',
#  '_Object1_width',
#  '_Object1_height']

# %%
display_object_detections(conn=s, 
                          table=dict(name='detTbl', where='_nObjects_ > 0'), 
                          coord_type='yolo', 
                          max_objects=30, 
                          num_plot=4,
                          n_col=2)

# %% [markdown]
# ## Split data into training and validation data

# %%
sampled_data = s.sampling.srs(table=dict(name='detTbl', where='_nObjects_ > 0'), samppct=90, samppct2=10, partind=True, output=dict(casout=dict(name='sampled_data', replace=True), copyvars='all', partindname='Partind')).OutputCasTables['casTable'][0]
trainData = sampled_data[sampled_data['Partind'] == 1]
validData = sampled_data[sampled_data['Partind'] == 2]
# Out:
# NOTE: Simple Random Sampling is in effect.
# NOTE: Using SEED=1380613771 for sampling.

# %%
labels = list(get_info_for_object_detection(s, table=trainData)[0].keys())
object_info_train = get_info_for_object_detection(s, table=trainData)
object_info_val = get_info_for_object_detection(s, table=validData)
object_counts_train = [object_info_train[0][val] for val in object_info_train[0]]
object_counts_val = [object_info_val[0][val] for val in object_info_val[0]]

fig,axes = plt.subplots(nrows = 1, ncols = 2, figsize=(20,5))
y_pos = np.arange(len(labels))
axes[0].set_title('Training', fontsize=16)
axes[0].bar(x=labels, height=object_counts_train)
axes[0].tick_params(axis="x", labelsize=14, rotation=45)
axes[1].set_title('Validation', fontsize=16)
axes[1].bar(x=labels, height=object_counts_val)
axes[1].tick_params(axis="x", labelsize=14, rotation=45)
plt.show()

# %%
len(trainData), len(validData)
# Out:
# (4779, 531)

# %% [markdown]
# # Model Setup
# ### The following step will be performed to setup the YOLOv2 model:
# 1. Create Anchors for YOLOv2 model using KMeans-Clustering (optional: check visually if anchors capture object ratios)
# 2. Use pre-built YOLOv2 architecture with customized parameters (n_classes, n_anchors, predictions_per_grid, etc.)
# 3. Load pretrained weights
# 4. Define data_specs (model-inputs & model-target)
# 5. Define Learning-Rate scheduler, Solver and Optimizer
# 6. Start Training

# %%
yolo_anchors = get_anchors(conn=s, 
                           data=trainData, 
                           n_anchors=15, 
                           coord_type='yolo')
yolo_anchors
# Out:
# (0.2660576171017093,
#  1.161396639741182,
#  0.14282923611380818,
#  0.428680854760535,
#  0.31546709851342575,
#  1.6489973694099227,
#  0.1631631712529879,
#  0.8301510633434217,
#  0.24593239842764153,
#  0.5765663665414114,
#  2.1269219092377725,
#  1.6816091543685807,
#  3.766067897252147,
#  2.2268333725845033,
#  0.4477755623286235,
#  1.9034338544470897,
#  7.542351850154357,
#  3.437343691200465,
#  0.11780099929516014,
#  0.3808499308049255,
#  1.0140991463215543,
#  0.7550813348428785,
#  0.4520300443220245,
#  1.1662984786750596,
#  1.4514722189801355,
#  2.732803334106591,
#  11.77874253853842,
#  8.158559560761429,
#  11.719334089287326,
#  7.599192063647798)

# %%
def plot_yolo_anchors(yolo_anchors, image_size, anchor_scale):
    anchor_image = np.zeros(image_size, np.int16)
    yolo_anchors = [yolo_anchors[ix:ix+2] for ix, _ in enumerate(yolo_anchors) if ix%2==0]
    x0,y0 = image_size[0]/2, image_size[1]/2
    for anchor in yolo_anchors:
        x1 = x0-anchor[0]/2*anchor_scale
        y1 = y0-anchor[1]/2*anchor_scale
        x2 = x0+anchor[0]/2*anchor_scale
        y2 = y0+anchor[1]/2*anchor_scale
        cv2.rectangle(anchor_image, (int(x1),int(y1)), (int(x2),int(y2)), (255,0,0), 2)
    plt.figure(figsize = (20,10))
    plt.imshow(anchor_image)
plot_yolo_anchors(yolo_anchors, image_size=(416,416), anchor_scale=150)

# %%
# person, airplane, stairway, car, fueltruck
yolo_model = Tiny_YoloV2(conn=s, 
                         n_classes=11, 
                         predictions_per_grid=15, 
                         anchors = yolo_anchors,
                         max_boxes=845, 
                         coord_type='yolo',
                         max_label_per_image = get_info_for_object_detection(s, table=trainData)[1],
                         class_scale=1.0, 
                         coord_scale=1.0, 
                         prediction_not_a_object_scale=1, 
                         object_scale=5,
                         detection_threshold=0.2, 
                         iou_threshold=0.2, 
                         width=416, 
                         height=416, 
                         grid_number=13)
# Out:
# NOTE: Input layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Pooling layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Convolution layer added.
# NOTE: Batch normalization layer added.
# NOTE: Convolution layer added.
# NOTE: Detection layer added.
# NOTE: Model compiled successfully.

# %%
yolo_model.load_weights(path='/data/notebooks/deep_learning_examples/models/object_detection/tiny_yolov2_313cls/Tiny-Yolov2_weights.sashdat')

# %%
data_specs = [DataSpec(type_='IMAGE', layer='Input1', data=['_image_']),
              DataSpec(type_='OBJECTDETECTION', layer='Detection1', data=object_detection_targets)]

# %%
lr_scheduler = PolynomialLR(learning_rate=0.001, power=1)

# %%
# lr_scheduler = ReduceLROnPlateau(conn=s, 
#                                  cool_down_iters=10, 
#                                  gamma=0.1, 
#                                  learning_rate=0.001, 
#                                  patience=5)
solver = MomentumSolver(momentum=0.9, 
                        lr_scheduler=lr_scheduler, 
                        clip_grad_max=100, 
                        clip_grad_min=-100)
optimizer = Optimizer(algorithm=solver, 
                      mini_batch_size=1, 
                      log_level=2, 
                      max_epochs=300, 
                      reg_l2=0.0005,
                      stagnation=50)
gpu = Gpu(devices=[0])
# Out:
# The following argument(s) learning_rate, learning_rate_policy, gamma, step_size, power are overwritten by the according arguments specified in lr_scheduler.

# %%
# Start Training
yolo_model.fit(data=trainData,
               valid_table=validData,
               optimizer=optimizer,
               data_specs=data_specs, 
               n_threads=8, 
               record_seed=54321,
               force_equal_padding=True, 
               gpu=gpu,
               save_best_weights=True)
# Out:
# NOTE: Training from scratch.
# WARNING: Using dataSpecs settings. Additional input or target option settings will be ignored.
# NOTE: Using michael-AERO-15-X9: 1 out of 1 available GPU devices.
# NOTE:  Synchronous mode is enabled.
# NOTE:  The total number of parameters is 11136912.
# NOTE:  The approximate memory cost is 511.00 MB.
# NOTE:  Loading weights cost       0.00 (s).
# NOTE:  Initializing each layer cost       4.01 (s).
# NOTE:  The total number of threads on each worker is 8.
# NOTE:  The total mini-batch size per thread on each worker is 1.
# NOTE:  The maximum mini-batch size across all workers for the synchronous mode is 8.
# NOTE:  Number of levels for the target variable:     11
# NOTE:  Levels for the target variable:
# NOTE:  Level      0: airplane
# NOTE:  Level      1: baggage_truck
# NOTE:  Level      2: bus
# NOTE:  Level      3: car
# NOTE:  Level      4: fuel_truck
# NOTE:  Level      5: ground_power
# NOTE:  Level      6: person
# NOTE:  Level      7: ramp_loader
# NOTE:  Level      8: rolling_stairway
# NOTE:  Level      9: stairway
# NOTE:  Level     10: tank_hose
# NOTE:  Epoch Learning Rate        Loss        IOU  Validation Loss   Validation IOU   Time(s)
# NOTE:  0         0.001           35.84     0.5979            31.45           0.5579    29.01
# NOTE:  1         0.001           26.92     0.6363            27.99           0.5799    27.45
# NOTE:  2         0.001           17.48     0.6621            22.76           0.6136    27.65
# NOTE:  3         0.001           13.39     0.6913            14.27           0.6639    27.73
# NOTE:  4         0.001           12.12     0.7176            12.99           0.6965    27.90
# NOTE:  5         0.001           11.51     0.7303            15.44           0.6905    28.01
# NOTE:  6         0.001           11.03     0.7403            13.37           0.6751    28.21
# NOTE:  7         0.001           10.81     0.7467            11.48            0.725    28.68
# NOTE:  8         0.001           10.26     0.7544            11.18           0.7501    28.46
# NOTE:  9         0.001           9.958     0.7668            11.91           0.7239    28.49
# NOTE:  10        0.001            7.86     0.7635            8.531           0.7544    28.57
# NOTE:  11        0.001           7.432     0.7702            8.633           0.7508    28.60
# NOTE:  12        0.001           7.349     0.7715             8.67           0.7495    28.64
# NOTE:  13        0.001           7.217     0.7743            9.209           0.7444    28.57
# NOTE:  14        0.001           7.164     0.7776            8.385           0.7541    28.52
# NOTE:  15       0.0009           6.925      0.787            8.312           0.7439    28.56
# NOTE:  16       0.0009           6.733     0.7891            7.978           0.7591    28.59
# NOTE:  17       0.0009           6.532     0.7946             8.13           0.7742    28.59
# NOTE:  18       0.0009           6.529     0.7964            8.396            0.767    28.83
# NOTE:  19       0.0009            5.26     0.7914            4.139           0.7358    28.51
# NOTE:  20       0.0009           2.099     0.7993            3.884           0.7492    28.57
# NOTE:  21       0.0009           1.988        0.8            3.797           0.7782    28.59
# NOTE:  22       0.0009           1.986     0.8056            3.491           0.7815    28.55
# NOTE:  23       0.0009           1.908      0.811            5.137           0.7414    28.50
# NOTE:  24       0.0009           1.855     0.8117            3.998            0.786    28.46
# NOTE:  25       0.0009           1.754      0.811            3.469           0.7892    28.50
# NOTE:  286      467E-7          0.3226     0.9306            2.261           0.8649    28.62
# NOTE:  287      433E-7          0.3219     0.9314             2.26           0.8649    28.60
# NOTE:  288        4E-5          0.3579       0.93            2.261            0.865    28.64
# NOTE:  289      367E-7          0.3476     0.9305            2.264            0.865    28.62
# NOTE:  290      333E-7          0.3177      0.932            2.259           0.8651    28.62
# NOTE:  291        3E-5          0.3006      0.932            2.262            0.865    28.62
# NOTE:  292      267E-7          0.3176     0.9307             2.26            0.865    28.62
# NOTE:  293      233E-7          0.3278     0.9291            2.241           0.8648    29.36
# NOTE:  294        2E-5          0.2973     0.9317             2.24           0.8651    29.00
# NOTE:  295      167E-7          0.3305     0.9321            2.242            0.865    28.80
# NOTE:  296      133E-7          0.3359     0.9301            2.245           0.8651    28.64
# NOTE:  297        1E-5          0.3429      0.932            2.244           0.8651    28.62
# NOTE:  298      667E-8          0.3127     0.9278            2.247           0.8652    28.64
# NOTE:  299      333E-8          0.2924     0.9308            2.248           0.8652    28.60
# NOTE:  The optimization reached the maximum number of epochs.
# NOTE:  The total time is    8784.20 (s).
# [ModelInfo]
#
#                                          Descr                         Value
#  0                                  Model Name                   tiny-yolov2
#  1                                  Model Type  Convolutional Neural Network
#  2                            Number of Layers                            25
#  3                      Number of Input Layers                             1
#  4                     Number of Output Layers                             0
#  5              Number of Convolutional Layers                             9
#  6                    Number of Pooling Layers                             6
#  7            Number of Fully Connected Layers                             0
#  8        Number of Batch Normalization Layers                             8
#  9                  Number of Detection Layers                             1
#  10                Number of Weight Parameters                      11131824
#  11                  Number of Bias Parameters                          5088
#  12           Total Number of Model Parameters                      11136912
#  13  Approximate Memory Cost for Training (MB)                           527
#
# [OptIterHistory]
#
#       Epoch  LearningRate       Loss  FitError    L2Norm  ValidLoss  ValidError
#  0        1      0.001000  35.841416  0.402149  1.643837  31.452783    0.442123
#  1        2      0.000997  26.923245  0.363677  1.635659  27.986994    0.420101
#  2        3      0.000993  17.484183  0.337912  1.623180  22.762829    0.386415
#  3        4      0.000990  13.386660  0.308677  1.612352  14.273614    0.336077
#  4        5      0.000987  12.124884  0.282426  1.601648  12.991019    0.303518
#  ..     ...           ...        ...       ...       ...        ...         ...
#  295    296      0.000017   0.330475  0.067869  0.319722   2.242178    0.135026
#  296    297      0.000013   0.335923  0.069851  0.319666   2.244765    0.134863
#  297    298      0.000010   0.342867  0.068007  0.319622   2.244385    0.134877
#  298    299      0.000007   0.312704  0.072181  0.319591   2.247478    0.134804
#  299    300      0.000003   0.292405  0.069188  0.319572   2.248008    0.134847
#
#  [300 rows x 7 columns]
#
# [OutputCasTables]
#
#           casLib                       Name      Rows  Columns  \
#  0  CASUSER(sas)  model_best_weights_17Q0dl  11142000        3
#  1  CASUSER(sas)        Tiny-Yolov2_weights  11142000        3
#
#                                              casTable
#  0  CASTable('model_best_weights_17Q0dl', caslib='...
#  1  CASTable('Tiny-Yolov2_weights', caslib='CASUSE...
#
# + Elapsed: 8.79e+03s, user: 2.18e+04s, sys: 48s, mem: 589mb

# %% [markdown]
# ## Verify Model Training
# Validation Loss should decrease over time. If Validation Loss increases - the model might be overfitting the data.<br>
# Additionally we can score our validation images with the trained model and visually verify the correctness of its predictions for some images.<br>
# In the last step we plot some object-detection measures, e.g. mean average precision.

# %%
plt.figure(figsize = (15,8))
plt.plot(yolo_model.training_history.tail(290)[['Loss','ValidLoss']])
plt.ylabel('ValidLoss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=16)
plt.title('Training History', fontsize=20)
plt.legend(['Loss','ValidLoss'], fontsize=16)
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.plot(yolo_model.training_history.tail(95)[['Loss','ValidLoss']])
plt.ylabel('ValidLoss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=16)
plt.title('Training History', fontsize=20)
plt.legend(['Loss','ValidLoss'], fontsize=16)
plt.show()

# %%
plt.figure(figsize = (15,8))
plt.plot(yolo_model.training_history.tail(80)[['Loss','ValidLoss']])
plt.ylabel('ValidLoss', fontsize=16)
plt.xlabel('Epoch', fontsize=16)
plt.xticks(fontsize=16)
plt.title('Training History', fontsize=20)
plt.legend(['Loss','ValidLoss'], fontsize=16)
plt.show()

# %%
yolo_model.set_weights(yolo_model.best_weights)
# Out:
# NOTE: Model weights attached successfully!

# %%
yolo_model.predict(data=validData, gpu=gpu)
# Out:
# NOTE: Using michael-AERO-15-X9: 1 out of 1 available GPU devices.
# [ScoreInfo]
#
#                           Descr         Value
#  0  Number of Observations Read           531
#  1  Number of Observations Used           531
#  2     Average IoU in Detection      0.857617
#  3                   Loss Error      3.994438
#
# [OutputCasTables]
#
#           casLib              Name  Rows  Columns  \
#  0  CASUSER(sas)  Valid_Res_qTZkXN   531    15215
#
#                                              casTable
#  0  CASTable('Valid_Res_qTZkXN', caslib='CASUSER(s...
#
# + Elapsed: 4.38s, user: 7.38s, sys: 0.393s, mem: 599mb

# %%
0.865154, 3.855208

# %%
display_object_detections(conn=s, 
                          table=yolo_model.valid_res_tbl, 
                          coord_type='yolo', 
                          max_objects=100, 
                          num_plot=4,
                          n_col=2)

# %%
evaluations = yolo_model.evaluate_object_detection(ground_truth=validData, coord_type='yolo', iou_thresholds=[0.55,0.60,0.65,0.70,0.85,0.90,0.95])
# Out:
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)
# Evaluating class: airplane (521 detections)
# Evaluating class: baggage_truck (222 detections)
# Evaluating class: bus (153 detections)
# Evaluating class: car (98 detections)
# Evaluating class: fuel_truck (202 detections)
# Evaluating class: ground_power (267 detections)
# Evaluating class: person (2230 detections)
# Evaluating class: ramp_loader (255 detections)
# Evaluating class: rolling_stairway (297 detections)
# Evaluating class: stairway (340 detections)
# Evaluating class: tank_hose (111 detections)

# %%
def plot_evaluation(evaluations, classes):
    num_iou = len(evaluations)
    num_classes = len(classes)
    fig,axes = plt.subplots(nrows = 1, ncols = num_iou, figsize=(50,5))
    fig.subplots_adjust(hspace=0.5, wspace=0.2)
    for ix, evaluation in enumerate(evaluations):
        iou_threshold = evaluations[ix]['IoU Threshold']
        num_classes = len(evaluations[ix]['Class Evaluation'])
        classes_labels = []
        classes_ap = []
        for i in range(0,num_classes):
            classes_labels.append(evaluation['Class Evaluation'][i]['class'])
            classes_ap.append(evaluation['Class Evaluation'][i]['AP'])
        axes[ix].bar(x=classes_labels, height=classes_ap)
        axes[ix].set_title('AP at IoU Threshold:{}'.format(iou_threshold), fontsize=16)
        axes[ix].set_ylabel('AP', fontsize=14)
        axes[ix].tick_params(axis="x", labelsize=14, rotation=90)
        axes[ix].set_ylim(0,1)
    return 
plot_evaluation(evaluations,labels)

# %%
yolo_model.save_to_astore('/data/notebooks/deep_learning_examples/Aircraft Turnaround Management/')
# Out:
# NOTE: Model astore file saved successfully.

# %%
yolo_model.save_weights_csv('/data/notebooks/deep_learning_examples/Aircraft Turnaround Management/')
# Out:
# NOTE: Model weights csv saved successfully.
